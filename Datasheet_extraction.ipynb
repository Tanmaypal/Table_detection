# %%
import pdfplumber
pdf=pdfplumber.open('C:\Data\DataSheet\\10011-4D1JCR-MAF2101-TEP-F-00-CRC301-D01-0016_r01_v2.1.pdf')
p0 = pdf.pages[1]
#print(p0.chars[1])

# %%
im= p0.to_image()
im

# %%
table=p0.extract_tables()

# %%
table
# Out:
# [[['ENPRO INDUSTRIES PVT. LTD.\nHEAT EXCHANGER SPECIFICATION SHEET\nJob No. 13188',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['Customer ATLAS COPCO Reference No.-',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['Address - Proposal No. -',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
# ...

# %%
b = []
for sublist in table[0]:
    cleaned = [elem for elem in sublist if elem is not None]
    if len(cleaned):  # anything left?
        b.append(cleaned)

print(b)
# Out:
# [['ENPRO INDUSTRIES PVT. LTD.\nHEAT EXCHANGER SPECIFICATION SHEET\nJob No. 13188'], ['Customer ATLAS COPCO Reference No.-'], ['Address - Proposal No. -'], ['Plant Location RELIANCE J3, ROGC, EPC-TECHNIP Date', '10/06/2014', 'Rev', '1'], ['Service of Unit LUBE OIL COOLER Item No. ME-CRC301-S160101A/B'], ['Size 257 x 2750 mm Type AES Horizontal Connected In 1 Parallel 1 Series'], ['Surf/Unit (Gross/Eff)', '9.216', '/', '9.049', 'm2 Shell/Unit 1 Surf/Shell (Gross/Eff)', '9.216', '/', '9.049', 'm2'], ['PERFORMANCE OF ONE UNIT'], ['Fluid Allocation', 'Shell Side', 'Tube Side\nCOOLING WATER\n15000 (250 LPM)'], ['Fluid Name', 'ISO VG 46'], ['Fluid Quantity, Total kg/hr', '8670 (170 LPM)'], ['Vapor (In/Out)', '-', '-', '-', '-'], ['Liquid', '8670', '8670', '15000', '15000'], ['Steam', '-', '-', '-', '-'], ['Water', '-', '-', '15000', '15000'], ['Noncondensables', '-', '-', '-', '-'], ['Temperature (In/Out)', '61.6', '50', '32.00', '35.16'], ['Specific Gravity', '0.846', '0.853', '0.9940', '0
# ...

# %%
for p in b:
    for number in p:
        if number=='Fluid Name':
            print(p.index(number))
            print(p[p.index(number):])
            print(p[p.index(number)+1])
            #print(p[p.index(number)+2])
            #print(p[p.index(number)+3])
            break
# Out:
# 0
# ['Fluid Name', 'ISO VG 46']
# ISO VG 46

# %%
tables.export('C:\Data\DataSheet\\foo.csv',f='csv',compress=True)
